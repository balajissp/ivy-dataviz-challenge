# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
df_raw = pd.read_csv('Wellbeing_and_lifestyle_data_Kaggle.csv')
df_raw.describe()
# Out:
#        FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED   CORE_CIRCLE  \
# count   15972.000000   15972.000000   15972.000000   15972.000000
# mean        2.922677       2.791573       5.232970       5.508077
# std         1.442694       1.367831       3.311912       2.840334
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       2.000000       2.000000       3.000000
# 50%         3.000000       3.000000       5.000000       5.000000
# 75%         4.000000       4.000000       8.000000       8.000000
# max         5.000000       5.000000      10.000000      10.000000
#
#        SUPPORTING_OTHERS  SOCIAL_NETWORK   ACHIEVEMENT    DONATION    \
# count    15972.000000      15972.000000   15972.000000  15972.000000
# mean         5.616454          6.474267       4.000751      2.715314
# std          3.242021          3.086672       2.755837      1.851586
# min          0.000000          0.000000       0.000000      0.000000
# ...

# %%
df = df_raw.copy()

# %%
sns.pairplot(df)

# %%
from dataprep.eda import create_report
create_report(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.python/current/lib/python3.12/site-packages/dask/array/__init__.py:27
#      26 from .chunk_types import register_chunk_type
# ---> 27 from .routines import (
#      28     take,
#      29     choose,
#      30     argwhere,
#      31     where,
#      32     coarsen,
#      33     insert,
#      34     shape,
#      35     union1d,
#      36     ravel,
#      37     roll,
#      38     unique,
#      39     squeeze,
#      40     ptp,
#      41     diff,
#      42     ediff1d,
#      43     gradient,
#      44     bincount,
#      45     digitize,
#      46     histogram,
#      47     cov,
#      48     array,
#      49     dstack,
#      50     vstack,
#      51     hstack,
#      52     compress,
#      53     extract,
#      54     round,
#      55     count_nonzero,
#      56     flatnonzero,
#      57     nonzero,
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df_av = AV.AutoViz('Wellbeing_and_lifestyle_data_Kaggle.csv')
# Out:
# Shape of your Data Set loaded: (15972, 24)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  18
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  2
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  1
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     24 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %%
# !pip install dataprep
# !pip install pandas-profiling[notebook]
# !pip install autoviz

# %%
from sklearn.decomposition import PCA, KernelPCA

# %%
model = PCA().fit()

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X=df.drop(columns=['WORK_LIFE_BALANCE_SCORE', 'Timestamp']).values, y=df['WORK_LIFE_BALANCE_SCORE'].values)
linreg.coef_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 linreg = LinearRegression()
# ----> 3 linreg.fit(X=df.drop(columns=['WORK_LIFE_BALANCE_SCORE', 'Timestamp']).values, y=df['WORK_LIFE_BALANCE_SCORE'].values)
#       4 linreg.coef_
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/linear_model/_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
# ...
